# %%
import numpy as np
import pandas as pd
import re
import math
from matplotlib import pyplot as plt
plt.style.use('ggplot')
import seaborn as sns

# %%
# !cat webmd_scrape.csv
# Out:
# comment,conditionInfo,dateTime,easeOfUse,effectiveness,helpful,reviewerInfo,satisfaction,supplement
# I take it for anxiety. 5-HTP stops the constant over active thinking and stress and allow me to rest.,Other,11/29/2007 5:24:02 AM,5,4,74,"emma_Colorado, 35-44 Female  on Treatment for less than 1 month (Consumer)",5,5-HTP
# I take it for anxiety. 5-HTP stops the constant over active thinking and stress and allow me to rest.,Other,9/25/2007 4:23:13 PM,5,4,74,"missindepend32, 25-34 Female  on Treatment for 1 to 6 months (Consumer)",5,5-HTP
# severe upper stomach discomfort,Other,9/26/2008 8:27:11 PM,2,3,8,55-64 Male  on Treatment for 1 to 6 months (Consumer),2,IRON
# severe upper stomach discomfort,Other,5/2/2008 5:33:37 AM,2,2,8,"katherine, 35-44 Female  on Treatment for 10 years or more (Consumer)",2,IRON
# severe upper stomach discomfort,Other,4/6/2008 4:05:23 PM,3,4,8,"robert mcfdonald, 75 or over Male  on Treatment for 5 to less than 10 years (Consumer)",3,IRON
# ...

# %%
webmd_df = pd.read_csv('webmd_scrape.csv')

# %%
webmd_df
# Out:
#                                                 comment  \
# 0     I take it for anxiety. 5-HTP stops the constan...
# 1     I take it for anxiety. 5-HTP stops the constan...
# 2                       severe upper stomach discomfort
# 3                       severe upper stomach discomfort
# 4                       severe upper stomach discomfort
# ...                                                 ...
# 7131  Only day one, and I only took one little round...
# 7132  Only day one, and I only took one little round...
# 7133  Only day one, and I only took one little round...
# 7134  Only day one, and I only took one little round...
# 7135  Only day one, and I only took one little round...
#
#                   conditionInfo               dateTime  easeOfUse  \
# 0                         Other  11/29/2007 5:24:02 AM          5
# 1                         Other   9/25/2007 4:23:13 PM          5
# 2                         Other   9/26/2008 8:27:11 PM          2
# ...

# %%
#df = df.set_index('index')

# %%
webmd_df.tail()
# Out:
#                                                 comment  \
# 7131  Only day one, and I only took one little round...
# 7132  Only day one, and I only took one little round...
# 7133  Only day one, and I only took one little round...
# 7134  Only day one, and I only took one little round...
# 7135  Only day one, and I only took one little round...
#
#                   conditionInfo               dateTime  easeOfUse  \
# 7131  General Health & Wellness   9/16/2014 8:41:45 AM          5
# 7132  General Health & Wellness  8/17/2014 10:46:37 AM          1
# 7133  General Health & Wellness  6/23/2014 10:33:32 AM          1
# 7134  General Health & Wellness   5/10/2014 7:46:40 PM          5
# 7135  General Health & Wellness   5/6/2014 11:03:58 AM          5
#
#       effectiveness  helpful  \
# 7131              4       21
# 7132              2       21
# 7133              1       21
# 7134              4       21
# 7135              5       21
#
# ...

# %%
webmd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7136 entries, 0 to 7135
# Data columns (total 9 columns):
# comment          7134 non-null object
# conditionInfo    7134 non-null object
# dateTime         7136 non-null object
# easeOfUse        7136 non-null int64
# effectiveness    7136 non-null int64
# helpful          7136 non-null int64
# reviewerInfo     6975 non-null object
# satisfaction     7136 non-null int64
# supplement       7136 non-null object
# dtypes: int64(4), object(5)
# memory usage: 501.9+ KB

# %%
df = webmd_df.copy()

# %%
df.shape
# Out:
# (7136, 9)

# %%
df.drop_duplicates(inplace=True) #removes duplicates

# %%
df.shape
# Out:
# (7128, 9)

# %%
df.isnull() #checking for null cells
# Out:
#       comment  conditionInfo  dateTime  easeOfUse  effectiveness  helpful  \
# 0       False          False     False      False          False    False
# 1       False          False     False      False          False    False
# 2       False          False     False      False          False    False
# 3       False          False     False      False          False    False
# 4       False          False     False      False          False    False
# ...       ...            ...       ...        ...            ...      ...
# 7131    False          False     False      False          False    False
# 7132    False          False     False      False          False    False
# 7133    False          False     False      False          False    False
# 7134    False          False     False      False          False    False
# 7135    False          False     False      False          False    False
#
#       reviewerInfo  satisfaction  supplement
# ...

# %%
df.isnull().sum()
# Out:
# comment            2
# conditionInfo      2
# dateTime           0
# easeOfUse          0
# effectiveness      0
# helpful            0
# reviewerInfo     161
# satisfaction       0
# supplement         0
# dtype: int64

# %%
df.fillna('None Provided', inplace=True) #fills in na with 'None Provided'

# %%
df.isnull().sum()
# Out:
# comment          0
# conditionInfo    0
# dateTime         0
# easeOfUse        0
# effectiveness    0
# helpful          0
# reviewerInfo     0
# satisfaction     0
# supplement       0
# dtype: int64

# %%
df.supplement.describe()
# Out:
# count          7128
# unique           77
# top       MELATONIN
# freq            473
# Name: supplement, dtype: object

# %%
top_10_reviewed_supplements = df.supplement.value_counts().head(10) #counts
top_10_reviewed_supplements
# Out:
# MELATONIN           473
# 5-HTP               382
# VITAMIN D           340
# COLLOIDAL SILVER    309
# MAGNESIUM           287
# HYALURONIC ACID     221
# FISH OIL            200
# KRILL OIL           191
# BIOTIN              190
# ASHWAGANDHA         149
# Name: supplement, dtype: int64

# %% [raw]
# interesting colloidal silver is a top 4 reviewed supplement. Check WebMD site, and it says "Despite promoter's claims, silver has no known function in the body and is not an essential mineral supplement.

# %%
top_10_conditions = df.conditionInfo.value_counts().head(10)
top_10_conditions
# Out:
# Other                        1398
# General Health & Wellness    1296
# Insomnia                      294
# Arthritis                     241
# Anxiety                       236
# Weight loss                   223
# Depression                    195
# Diabetes                      154
# High blood pressure            90
# Fibromyalgia                   80
# Name: conditionInfo, dtype: int64

# %%
df.corr() #correlation
# Out:
#                easeOfUse  effectiveness   helpful  satisfaction
# easeOfUse       1.000000       0.642471  0.077216      0.634976
# effectiveness   0.642471       1.000000  0.076374      0.891712
# helpful         0.077216       0.076374  1.000000      0.088164
# satisfaction    0.634976       0.891712  0.088164      1.000000

# %%
reviewerInfo = df[['reviewerInfo']]
reviewerInfo
# Out:
#                                            reviewerInfo
# 0     emma_Colorado, 35-44 Female  on Treatment for ...
# 1     missindepend32, 25-34 Female  on Treatment for...
# 2     55-64 Male  on Treatment for 1 to 6 months (Co...
# 3     katherine, 35-44 Female  on Treatment for 10 y...
# 4     robert mcfdonald, 75 or over Male  on Treatmen...
# ...                                                 ...
# 7131  artker, 35-44 Female  on Treatment for less th...
# 7132  jeanjackie, 55-64 Female  on Treatment for les...
# 7133  michmichfly, 55-64 Female  on Treatment for le...
# 7134  jfsharp, 75 or over Male  on Treatment for 10 ...
# 7135  Olga, 45-54 Female  on Treatment for 1 to 6 mo...
#
# [7128 rows x 1 columns]

# %%
df.loc[7000] #.loc gets the row based on the index, here we are accessing index 7000
# Out:
# comment          No Script or health Insurance needed to place ...
# conditionInfo                                            Hair loss
# dateTime                                      7/27/2018 3:28:04 PM
# easeOfUse                                                        5
# effectiveness                                                    5
# helpful                                                         26
# reviewerInfo     19-24 Female  on Treatment for 2 to less than ...
# satisfaction                                                     5
# supplement                                                  BIOTIN
# Name: 7000, dtype: object

# %%
def age_range(x):
    result = re.findall('\d{2}-\d{2}',x)
    if result == '':
        return 
    else:
        return result

# %%
age_range('55-64 Male on Treatment for 1 to 6 70 months (Co.')
# Out:
# ['55-64']

# %%
df['age_range'] = df.reviewerInfo.apply(lambda row: age_range(row))

# %%
df
# Out:
#                                                 comment  \
# 0     I take it for anxiety. 5-HTP stops the constan...
# 1     I take it for anxiety. 5-HTP stops the constan...
# 2                       severe upper stomach discomfort
# 3                       severe upper stomach discomfort
# 4                       severe upper stomach discomfort
# ...                                                 ...
# 7131  Only day one, and I only took one little round...
# 7132  Only day one, and I only took one little round...
# 7133  Only day one, and I only took one little round...
# 7134  Only day one, and I only took one little round...
# 7135  Only day one, and I only took one little round...
#
#                   conditionInfo               dateTime  easeOfUse  \
# 0                         Other  11/29/2007 5:24:02 AM          5
# 1                         Other   9/25/2007 4:23:13 PM          5
# 2                         Other   9/26/2008 8:27:11 PM          2
# ...

# %%
df.isnull().sum()
# Out:
# comment          0
# conditionInfo    0
# dateTime         0
# easeOfUse        0
# effectiveness    0
# helpful          0
# reviewerInfo     0
# satisfaction     0
# supplement       0
# age_range        0
# dtype: int64

# %%
top_10_age_bracket = df.age_range.value_counts().head(10)

# %%
df.columns
# Out:
# Index(['comment', 'conditionInfo', 'dateTime', 'easeOfUse', 'effectiveness',
#        'helpful', 'reviewerInfo', 'satisfaction', 'supplement', 'age_range'],
#       dtype='object')

# %%
df.rename(columns={
    'comment':'comment', 
    'conditionInfo':'condition_info', 
    'dateTime':'date_time',
    'easeOfUse':'ease_of_use', 
    'effectiveness':'effectiveness',
    'helpful':'helpful', 
    'reviewerInfo':'reviewer_info', 
    'satisfaction':'satisfaction', 
    'supplement':'supplement_name', 
    'age_range':'age_range'
    }, inplace=True)

# %%
df.reviewer_info = df.reviewer_info.str.lower() #lowercase all reviewer info

# %%
df.comment = df.comment.str.lower() #lowercase all comment string

# %%
df.helpful.value_counts().head(10) #top 10 most helpful comment
# Out:
# 0     695
# 1     551
# 2     459
# 3     454
# 4     315
# 6     254
# 5     243
# 9     210
# 7     209
# 10    198
# Name: helpful, dtype: int64

# %%
df
# Out:
#                                                 comment  \
# 0     i take it for anxiety. 5-htp stops the constan...
# 1     i take it for anxiety. 5-htp stops the constan...
# 2                       severe upper stomach discomfort
# 3                       severe upper stomach discomfort
# 4                       severe upper stomach discomfort
# ...                                                 ...
# 7131  only day one, and i only took one little round...
# 7132  only day one, and i only took one little round...
# 7133  only day one, and i only took one little round...
# 7134  only day one, and i only took one little round...
# 7135  only day one, and i only took one little round...
#
#                  condition_info              date_time  ease_of_use  \
# 0                         Other  11/29/2007 5:24:02 AM            5
# 1                         Other   9/25/2007 4:23:13 PM            5
# 2                         Other   9/26/2008 8:27:11 PM            2
# ...

# %%
num_of_female_reviews = df[df['reviewer_info'].str.match('female' or 'woman')].shape
num_of_female_reviews
# Out:
# (52, 10)

# %%
num_of_male_reviews = df[df['reviewer_info'].str.match('male')].shape
num_of_male_reviews
# Out:
# (27, 10)

# %%
def determine_sex(x):
    if x.find('female') or x.find('women') >=0:
        return 'female'
    elif x.find(' male ') or x.find(' man ') >=0:
        return 'male'
    else:
        return ''

# %%
dsfsdfa = df.copy()

# %%
dsfsdfa['reviewer_sex'] = dsfsdfa.reviewer_info.apply(determine_sex)

# %%
dsfsdfa.head(10)
# Out:
#                                              comment condition_info  \
# 0  i take it for anxiety. 5-htp stops the constan...          Other
# 1  i take it for anxiety. 5-htp stops the constan...          Other
# 2                    severe upper stomach discomfort          Other
# 3                    severe upper stomach discomfort          Other
# 4                    severe upper stomach discomfort          Other
# 5                                           no enery          Other
# 6                                           no enery          Other
# 7                                           no enery          Other
# 8  my adhd and ocd are particularly bad and work ...           ADHD
# 9  i recommend hyaluronic acid to everyone who ha...      Arthritis
#
#                 date_time  ease_of_use  effectiveness  helpful  \
# 0   11/29/2007 5:24:02 AM            5              4       74
# 1    9/25/2007 4:23:13 PM            5              4       74
# ...

# %% [raw]
# https://www.ibisworld.com/united-states/market-research-reports/vitamin-supplement-manufacturing-industry/
#
# Total Revenue in 2019 - $33bn
# Number of Business - 1456
# Annual Growth 2014-2019 - 2%
# Industry Employement - 37,302

# %% [raw]
# https://www.advisory.com/daily-briefing/2019/02/13/fda-supplements
#
# 1994 Dietary Supplement Heath and Education (DSHEA), FDA regulates dietary supplements as food, which means they are not subject to premarket approval or the same effectiveness and safety testing required for drugs.

# %% [raw]
# https://www.fda.gov/food/dietary-supplements
# - FDA regules both finished dietary supplement products and dietary ingredients.
# - FDA regules dietary supplements under a different set of regulations than those covering "conventional" food and drug products.
# - Under the Dietary Supplement Health and Education Act of 1994 (DSHEA):
# - Manufacturers and distributors of dietary supplements and dietary ingredients are prohibited from marketing products that are adulterated or misbranded
#     - This means that these firms are responsible for evaluating the safety and labeling of their products before marketing to ensure that they meet all the requirements of DSHEA and FDA regulations
#     - FDA is responsible for taking action against any adulterated or misbranded dietary supplement product after it reaches the market

# %%
df['comment'].value_counts()
# Out:
# good                                                                                                                                                                                                                                                                                                                                                                                                                                           72
# no script or health insurance needed to place and order with 10% discount for all purchased. it was nice to have some from them, i just hit them at. whatsapp only: +1(252)4601212, wickr or kik: peterking2014. email:                                                                                                                                                                                                                        65
# ...

# %%
df['comment'] = df['comment'].apply(lambda x: re.sub('\s+', ' ', x))

# %%
df['comment'] = df['comment'].apply(lambda x: re.sub('[^\w\s]', '', x))

# %%
df['comment']
# Out:
# 0       i take it for anxiety 5htp stops the constant ...
# 1       i take it for anxiety 5htp stops the constant ...
# 2                         severe upper stomach discomfort
# 3                         severe upper stomach discomfort
# 4                         severe upper stomach discomfort
#                               ...
# 7131    only day one and i only took one little round ...
# 7132    only day one and i only took one little round ...
# 7133    only day one and i only took one little round ...
# 7134    only day one and i only took one little round ...
# 7135    only day one and i only took one little round ...
# Name: comment, Length: 7128, dtype: object

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
print(stop)
type(stop)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
df['comment'] = df['comment'].apply(lambda text: " ".join(word for word in text.split() if word not in stop))

# %%
df['comment']
# Out:
# 0       take anxiety 5htp stops constant active thinki...
# 1       take anxiety 5htp stops constant active thinki...
# 2                         severe upper stomach discomfort
# 3                         severe upper stomach discomfort
# 4                         severe upper stomach discomfort
#                               ...
# 7131    day one took one little round pill took yester...
# 7132    day one took one little round pill took yester...
# 7133    day one took one little round pill took yester...
# 7134    day one took one little round pill took yester...
# 7135    day one took one little round pill took yester...
# Name: comment, Length: 7128, dtype: object

# %%
from nltk.tokenize import word_tokenize

# %%
from textblob import TextBlob

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# %%
TextBlob(df['comment'][5]).ngrams(2)
# Out:
# []

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud(background_color="white", max_words=2000, width=800, height=400)
# generate word cloud
wc.generate(' '.join(df['comment']))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(12, 6))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
range(5)
# Out:
# range(0, 5)

# %%
print(range(0,5))
# Out:
# range(0, 5)

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
reviews = 5

# %%
for i in range(1,reviews+1))
# Out:
#   File "<ipython-input-68-1bd961a4fec7>", line 1
#     for i in range(1,reviews+1))
#                                ^
# SyntaxError: invalid syntax

# %%
[i+0 for i in range(1, reviews+1)]
# Out:
# [1, 2, 3, 4, 5]

# %%
for i in range(5):
    div_num = str(5 + i)
    print(div_num)
# Out:
# 5
# 6
# 7
# 8
# 9
